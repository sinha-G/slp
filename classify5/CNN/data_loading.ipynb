# %% [markdown]
# <h1> Outline </h1>
# Try to figure out how to load the data quickly. First we import packages.

# %%
import os as os
import sys
import numpy as np
# import pandas as pd
import tqdm
# import slippi as slp
import gzip
from joblib import Parallel, delayed
from multiprocessing import Manager
# from numba import njit, prange
# import cupy as cp
import gzip

# %% [markdown]
# <h1> Preliminary Variables </h1>

# %%
load_path = 'C:/Users/jaspa/Grant ML/slp/data/character_batches'
load_files = [file for file in os.listdir(load_path) if file.endswith('.gz')]

data_type_character_encode = np.bool_

# %%
# Function to load data and make the labels
def load_file(file,load_path,data_with_labels_list):
    
    # Load compressed character inputs file
    full_path = os.path.join(load_path,file)
    with gzip.open(full_path, 'rb') as f:
        data = np.load(f)
    
    # One hot encode the charater inputs being loaded
    if 'FOX' in file:
        one_hot_encode_character =  np.array([1, 0, 0, 0, 0], dtype=data_type_character_encode)
    elif 'FALCO' in file:
        one_hot_encode_character = np.array([0, 1, 0, 0, 0], dtype=data_type_character_encode)
    elif 'MARTH' in file:
        one_hot_encode_character = np.array([0, 0, 1, 0, 0], dtype=data_type_character_encode)
    elif 'SHEIK' in file:
        one_hot_encode_character = np.array([0, 0, 0, 1, 0], dtype=data_type_character_encode)
    elif 'JIGGLYPUFF' in file:
        one_hot_encode_character = np.array([0, 0, 0, 0, 1], dtype=data_type_character_encode)
    
    labels = np.tile(one_hot_encode_character, (data.shape[0],1))
    data_with_labels_list.append([data, labels])
    
    # data_with_labels_list.append([data])

# %%
# Specify the number of files to load
num_files = -1

# Create shared lists to store results
manager = Manager()
data_with_labels_list = manager.list()

# Use joblib to load the data
Parallel(n_jobs=-1, verbose=1)(delayed(load_file)(file, load_path, data_with_labels_list) 
                               for file in tqdm.tqdm(load_files[:num_files]))
# Out:
#   0%|          | 0/723 [00:00<?, ?it/s][Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
#   7%|▋         | 48/723 [00:01<00:19, 35.52it/s] [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
#  27%|██▋       | 192/723 [00:05<00:15, 35.14it/s][Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:    5.5s
#  60%|█████▉    | 432/723 [00:12<00:08, 34.01it/s][Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed:   12.9s
# 100%|██████████| 723/723 [00:21<00:00, 34.40it/s]
# [Parallel(n_jobs=-1)]: Done 723 out of 723 | elapsed:   22.3s finished
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# Assuming data_with_labels_list is defined and contains sublists, with each sublist's first element being a NumPy array
first_elements = [sublist[0] for sublist in data_with_labels_list]  # Extract the first element of each sublist

# Stack these first elements vertically
game_data_array = np.vstack(first_elements)

# Check size and shape
print('Size in MB:', sys.getsizeof(game_data_array) / 1e6)
print('Size in GB:', sys.getsizeof(game_data_array) / 1e9)
print(game_data_array.shape)
# Out:
# Size in MB: 32451.268752
# Size in GB: 32.451268752

# %%
# Define the path and filename
path = 'C:/Users/jaspa/Grant ML/slp/data/classify_5_data.npy'

# Save the array
np.save(path,game_data_array)

# Delete the array to save memory
del(game_data_array)

# %%
# Assuming data_with_labels_list is defined and contains sublists, with each sublist's first element being a NumPy array
second_elements = [sublist[1] for sublist in data_with_labels_list]  # Extract the second element of each sublist

# Stack these first elements vertically
labels_array = np.vstack(second_elements)

# Now you can check the size in MB and GB labels_array
print('Size in MB:', sys.getsizeof(labels_array) / 1e6)
print('Size in GB:', sys.getsizeof(labels_array) / 1e9)
print(labels_array.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 9
#       7 # Now you can check the size in MB and GB as you intended
#       8 import sys
# ----> 9 print('Size in MB:', sys.getsizeof(game_data_array) / 1e6)
#      10 print('Size in GB:', sys.getsizeof(game_data_array) / 1e9)
#
# NameError: name 'game_data_array' is not defined

# %%
# Define your path and filename
path = 'C:/Users/jaspa/Grant ML/slp/data/classify_5_labels.npy'

# Save the array
np.save(path,labels_array)
